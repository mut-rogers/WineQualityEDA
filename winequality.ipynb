# %%
# Loading the necessary libraries 
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 

# Loading the dataset 
wine_dataset = pd.read_csv("winequality.csv")

# %% [markdown]
# #### There are several questions that we can explore using the Wine Quality Dataset. These questions are outlined below.
# 1. What is the distribution of different of different quality ratings?
#
# 2. How does different chemical properties vary with wine quality?
#
# 3. Are there any relationship between different chemical properties?

# %% [markdown]
# ### 1. What is the distribution of different quality ratings?
# - The question wants us to investigate the distribution of wine quality ratings to discover how many wines faill into each wine quality rating.

# %%
wine_dataset.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
# Using countplot to visualize the distribution
sns.countplot(data=wine_dataset, x="quality") 

plt.xlabel("Wine Quality") 
plt.ylabel("Frequency") 
plt.title("Distribution of Wine Quality Ratings")
# Out:
# Text(0.5, 1.0, 'Distribution of Wine Quality Ratings')

# %%
# We can also introduce a hue for wine type 
sns.countplot(data=wine_dataset, x="quality", hue="type")

plt.xlabel("Wine Quality") 
plt.ylabel("Frequency") 
plt.title("Distribution of Wine Quality Ratings")
# Out:
# Text(0.5, 1.0, 'Distribution of Wine Quality Ratings')

# %% [markdown]
# - The countplot reveals some information about the wine quality ratings. The quality ratings range between 3-9 and the majority of wines fall between 5 and 6. As the quality of wine moves away from the central range, the number of wines reduces. That is, the count of wines at ratings 3-4 and 8-9 is low.

# %% [markdown]
# ### 2. How does different chemical properties vary with wine quality?

# %%
wine_dataset.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
sns.boxplot(data=wine_dataset, y="alcohol", x="quality", hue="type")
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
wine_dataset.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
# We can also create a heatmap and see how quality correlates with the chemicals.
wine_corr = wine_dataset.loc[:, "fixed acidity":"quality"].corr()

plt.figure(figsize=(10, 10))
sns.heatmap(wine_corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### 4. How does sthe pH level, affect the perceived quality of wine?
# - Here we are investigating how the pH level affects the quality ratings of the wines.

# %%
wine_dataset.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
sns.boxplot(wine_dataset, x="quality", y="pH")
# Out:
# <Axes: xlabel='quality', ylabel='pH'>

# %% [markdown]
# The pH value tends to slightly increase with increase in wine quality. The maybe as a result of product prefferences.

# %% [markdown]
# ### 5. Where there are differences in wine quality ratings between red and white wine

# %%
wine_dataset.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# 2       0.44     10.1        6
# 3       0.40      9.9        6
# 4       0.40      9.9        6

# %%
# Getting the average wine quality ratings for each time 
wine_dataset.groupby("type").quality.mean()
# Out:
# type
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %%
# We can visualize the aboves as follows 
sns.boxplot(wine_dataset, x="type", y="quality")

plt.title("Distribution of Quality Rating by Wine")
plt.ylabel("Wine Quality")
plt.xlabel("Wine Type")
# Out:
# Text(0.5, 0, 'Wine Type')

# %% [markdown]
# - There was no significant difference in wine quality ratings between "white" and 'red" wines.
